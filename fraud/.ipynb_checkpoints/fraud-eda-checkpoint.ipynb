# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
fraud = pd.read_csv('Fraud_Data.csv')
ip = pd.read_csv('IpAddress_to_Country.csv')

# %%
fraud.describe()
# Out:
#              user_id  purchase_value            age    ip_address  \
# count  151112.000000   151112.000000  151112.000000  1.511120e+05
# mean   200171.040970       36.935372      33.140704  2.152145e+09
# std    115369.285024       18.322762       8.617733  1.248497e+09
# min         2.000000        9.000000      18.000000  5.209350e+04
# 25%    100642.500000       22.000000      27.000000  1.085934e+09
# 50%    199958.000000       35.000000      33.000000  2.154770e+09
# 75%    300054.000000       49.000000      39.000000  3.243258e+09
# max    400000.000000      154.000000      76.000000  4.294850e+09
#
#                class
# count  151112.000000
# mean        0.093646
# std         0.291336
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000

# %%
fraud['signup_time'] = pd.to_datetime(fraud['signup_time'])
fraud['purchase_time'] = pd.to_datetime(fraud['purchase_time'])

# %%
fraud['time_to_purchase'] = fraud['purchase_time'] - fraud['signup_time']

# %%
fraud.head()
# Out:
#    user_id         signup_time       purchase_time  purchase_value  \
# 0    22058 2015-02-24 22:55:49 2015-04-18 02:47:11              34
# 1   333320 2015-06-07 20:39:50 2015-06-08 01:38:54              16
# 2     1359 2015-01-01 18:52:44 2015-01-01 18:52:45              15
# 3   150084 2015-04-28 21:13:25 2015-05-04 13:54:50              44
# 4   221365 2015-07-21 07:09:52 2015-09-09 18:40:53              39
#
#        device_id source browser sex  age    ip_address  class  \
# 0  QVPSPJUOCKZAR    SEO  Chrome   M   39  7.327584e+08      0
# 1  EOGFQPIZPYXFZ    Ads  Chrome   F   53  3.503114e+08      0
# 2  YSSKYOSJHPPLJ    SEO   Opera   M   53  2.621474e+09      1
# 3  ATGTXKYKUDUQN    SEO  Safari   M   41  3.840542e+09      0
# 4  NAUITBZFJKHWW    Ads  Safari   M   45  4.155831e+08      0
#
#    time_to_purchase
# 0  52 days 03:51:22
# 1   0 days 04:59:04
# 2   0 days 00:00:01
# 3   5 days 16:41:25
# 4  50 days 11:31:01

# %%
ip.head()
# Out:
#    lower_bound_ip_address  upper_bound_ip_address    country
# 0              16777216.0                16777471  Australia
# 1              16777472.0                16777727      China
# 2              16777728.0                16778239      China
# 3              16778240.0                16779263  Australia
# 4              16779264.0                16781311      China

# %%
country_ip = {}
for i in xrange(len(fraud)):
    current = fraud['ip_address'].iloc[i]
    user = fraud['user_id'].iloc[i]
    for j in xrange(len(ip)):
        lower = ip['lower_bound_ip_address'].iloc[j]
        upper = ip['upper_bound_ip_address'].iloc[j]
        country = ip['country'].iloc[j]
        if lower <= current and current <= upper:
            print j, country
            country_ip[user] = country
            break
        else:
            continue
# Out:
# Japan
# United States
# United States
# United States
# Canada
# United States
# China
# United States
# United States
# Brazil
# India
# United States
# Argentina
# United Kingdom
# China
# United States
# United States
# United States
# United States
# United States
# South Africa
# United States
# United States
# China
# Japan
# United States
# United States
# Germany
# United States
# China
# China
# Japan
# Mexico
# United States
# Brazil
# United States
# United States
# Sweden
# Korea Republic of
# Brazil
# Peru
# United States
# United States
# Portugal
# Bangladesh
# Korea Republic of
# France
# United States
# France
# Taiwan; Republic of China (ROC)
# Russian Federation
# United States
# Belgium
# Germany
# United Kingdom
# Korea Republic of
# United States
# Korea Republic of
# Denmark
# China
# China
# United Kingdom
# Korea Republic of
# United Kingdom
# United States
# United States
# United States
# United States
# United States
# Korea Republic of
# South Africa
# Korea Republic of
# United States
# United States
# Netherlands
# United States
# United States
# United States
# Iran (ISLAMIC Republic Of)
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United Kingdom
# United States
# Japan
# United States
# Germany
# Japan
# Brazil
# Taiwan; Republic of China (ROC)
# United Kingdom
# Croatia (LOCAL Name: Hrvatska)
# United States
# Viet Nam
# United States
# China
# Belgium
# United States
# United States
# United States
# Norway
# Denmark
# United States
# United States
# Taiwan; Republic of China (ROC)
# United States
# China
# United States
# United States
# China
# United States
# France
# United States
# Ukraine
# China
# Cyprus
# Israel
# United States
# United States
# United States
# France
# United States
# United States
# Australia
# Japan
# United Kingdom
# India
# United States
# Japan
# China
# United States
# Viet Nam
# Japan
# Italy
# United States
# United States
# India
# Norway
# China
# United States
# Japan
# United States
# United States
# United States
# China
# Korea Republic of
# Iran (ISLAMIC Republic Of)
# China
# United States
# United States
# Turkey
# United States
# Brazil
# United States
# China
# United States
# United States
# United States
# China
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# Moldova Republic of
# United States
# China
# Germany
# France
# Chile
# United States
# Italy
# United States
# Netherlands
# United States
# United States
# China
# United States
# United States
# Japan
# Taiwan; Republic of China (ROC)
# Czech Republic
# China
# United States
# United States
# Japan
# United States
# United States
# China
# United States
# United States
# United States
# Japan
# United States
# United States
# United States
# United States
# United States
# Italy
# United States
# United States
# United States
# United States
# Korea Republic of
# United States
# United States
# Colombia
# Australia
# United States
# India
# United States
# United States
# United States
# China
# Viet Nam
# United Kingdom
# United States
# United States
# Italy
# United States
# Japan
# Germany
# United States
# United States
# United States
# Algeria
# United States
# China
# Taiwan; Republic of China (ROC)
# China
# Malaysia
# Japan
# United States
# Korea Republic of
# United States
# Germany
# United States
# United States
# Brazil
# Greece
# Seychelles
# United States
# United States
# Kyrgyzstan
# Brazil
# Malaysia
# United States
# United States
# Sweden
# Brazil
# Argentina
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-ce873df5299c> in <module>()
#       4     user = fraud['user_id'].iloc[i]
#       5     for j in xrange(len(ip)):
# ----> 6         lower = ip['lower_bound_ip_address'].iloc[j]
#       7         upper = ip['upper_bound_ip_address'].iloc[j]
#       8         country = ip['country'].iloc[j]
#
# /Users/ernestpicato/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#    1310             return self._getitem_tuple(key)
#    1311         else:
# -> 1312             return self._getitem_axis(key, axis=0)
#    1313
#    1314     def _getitem_axis(self, key, axis=0):
#
# /Users/ernestpicato/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_axis(self, key, axis)
#    1628                 self._is_valid_integer(key, axis)
#    1629
# -> 1630             return self._get_loc(key, axis=axis)
#    1631
#    1632     def _convert_to_indexer(self, obj, axis=0, is_setter=False):
#
# /Users/ernestpicato/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _get_loc(self, key, axis)
#     103
#     104     def _get_loc(self, key, axis=0):
# --> 105         return self.obj._ixs(key, axis=axis)
#     106
#     107     def _slice(self, obj, axis=0, kind=None):
#
# /Users/ernestpicato/anaconda/lib/python2.7/site-packages/pandas/core/series.pyc in _ixs(self, i, axis)
#     587                     return self.take(i, axis=axis, convert=True)
#     588                 else:
# --> 589                     return _index.get_value_at(self, i)
#     590
#     591     @property
#
# TypeError: Argument 'arr' has incorrect type (expected numpy.ndarray, got Series)

# %%
len(fraud), len(ip)

# %%
ip.describe()

# %%
user = fraud['user_id'].iloc[0]
current = fraud['ip_address'].iloc[0]
lower = ip['lower_bound_ip_address'].iloc[0]
upper = ip['upper_bound_ip_address'].iloc[0]

# %%
user, current, lower, upper

# %%
current/(10**9)
